# %% [markdown]
# ## Strategy:
# - Check the sp500 to determine if market is stable.
# - If stable, enter long trade
# - If market rally and there is a 5% gain, close the position
# - Create 3% stop loss

# %%
## Get minutebar from alpaca

# %%
import datetime
import threading

import alpaca_trade_api as tradeapi
import time
from alpaca_trade_api.rest import TimeFrame
import pandas as pd

import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# PACA_KEY = os.getenv('ALPACA_API_KEY')
KEY="PKUMDZ81BB9ZBX7NV8FG"
# PACA_SECRET = os.getenv('ALPACA_SECRET_KEY')
SECRET ="7R1ub9iweFPuvUYpgV3x0fVSIbniQkf4Gf9i1loF"
PACA_URL = "https://paper-api.alpaca.markets"


# Define the symbol and time range for the trade data
symbol = 'AAPL'
start_date = '2023-01-01'
end_date = '2023-01-31'

# Initialize the Alpaca API
# api = tradeapi.REST(PACA_KEY, PACA_SECRET, PACA_URL, api_version='v2')
api = tradeapi.REST(KEY, SECRET, PACA_URL, api_version='v2')
trades = api.get_trades(symbol, start=start_date, end=end_date)

for trade in trades:
    print(f"Timestamp: {trade.t}, Price: {trade.p}, Size: {trade.s}")

# %%
from datetime import datetime
import threading
from alpaca_trade_api.rest import REST, TimeFrame
import time
import pandas as pd
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()
api = REST()

start_time = "2021-06-08"
# end_time = "2021-06-08"
minutebar = TimeFrame.Minute

api.get_bars("AAPL", 
             minutebar, 
             start=start_time, 
            #  end=end_time,
             adjustment='raw', 
             limit=10).df
# Out:
#                             close    high     low  trade_count    open  \
# timestamp
# 2021-06-08 08:00:00+00:00  126.00  126.10  125.96           53  126.10
# 2021-06-08 08:01:00+00:00  125.98  125.98  125.96           16  125.96
# 2021-06-08 08:02:00+00:00  126.04  126.04  125.98           29  126.00
# 2021-06-08 08:03:00+00:00  126.10  126.10  126.09           20  126.09
# 2021-06-08 08:04:00+00:00  126.16  126.16  126.10           67  126.10
# 2021-06-08 08:07:00+00:00  126.02  126.04  126.00           25  126.02
# 2021-06-08 08:09:00+00:00  126.09  126.10  126.09           30  126.09
# 2021-06-08 08:10:00+00:00  126.07  126.07  126.07            9  126.07
# 2021-06-08 08:11:00+00:00  126.09  126.09  126.08            9  126.08
# 2021-06-08 08:12:00+00:00  126.01  126.07  126.01           17  126.07
#
#                            volume        vwap
# timestamp
# 2021-06-08 08:00:00+00:00    2923  126.039410
# 2021-06-08 08:01:00+00:00     896  125.972823
# 2021-06-08 08:02:00+00:00    1315  126.003077
# 2021-06-08 08:03:00+00:00    1381  126.098126
# 2021-06-08 08:04:00+00:00    1891  126.117143
# 2021-06-08 08:07:00+00:00    1131  126.022278
# 2021-06-08 08:09:00+00:00    2912  126.090540
# 2021-06-08 08:10:00+00:00     257  126.070000
# 2021-06-08 08:11:00+00:00     620  126.082963
# 2021-06-08 08:12:00+00:00    4241  126.026739
